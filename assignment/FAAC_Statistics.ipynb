\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    4.93, 3.99, 3.6, 3.95, 3.57, 3.97, 5.64, 4.03, 5.44, 4.79, 4.55, 5.16
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Katsina State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    4.93, 2.49, 2.25, 2.46, 2.23, 2.47, 3.53, 2.53, 3.4, 2.96, 2.84, 3.24
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Kebbi State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    2.14, 2.47, 2.22, 2.44, 2.18, 2.46, 3.54, 2.51, 3.42, 2.96, 2.83, 3.23
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Kogi State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    1.6, 1.84, 1.66, 1.82, 1.65, 1.82, 0.16, 1.86, 2.51, 2.18, 2.09, 2.37
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Kwara State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    5.74, 6.1, 5.63, 6.07, 6.07, 6.11, 7.5, 6.15, 7.6, 6.87, 7.65, 7.81
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Lagos State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    5.74, 1.57, 1.42, 1.55, 1.38, 1.55, 2.25, 2.57, 2.17, 1.87, 1.8, 2.05
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Nasarawa State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    2.63, 3, 2.71, 2.97, 2.68, 2.99, 4.26, 3.04, 4.12, 3.58, 3.42, 3.89
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Niger State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    1.85, 2.11, 1.91, 2.11, 1.92, 2.13, 3.04, 2.19, 2.96, 2.56, 2.45, 2.78
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Ogun State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    1.79, 2.07, 1.87, 2.03, 1.84, 2.05, 2.92, 2.09, 2.84, 2.45, 2.35, 2.67
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Ondo State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    2.43, 2.79, 2.48, 2.76, 2.5, 2.78, 3.95, 2.83, 3.83, 3.34, 3.2, 3.63
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Osun State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    3.22, 3.64, 3.28, 3.64, 3.4, 3.76, 5.26, 3.82, 5.07, 4.47, 4.14, 4.68
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Oyo State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    3.22, 2.2, 1.98, 2.18, 1.95, 2.18, 3.11, 2.21, 3, 2.62, 2.51, 2.85
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Plateau State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    2.71, 3.05, 2.76, 3.08, 2.93, 3.19, 4.35, 3.22, 4.22, 3.75, 3.34, 3.73
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Rivers State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    2.32, 2.67, 2.41, 2.64, 2.37, 2.65, 3.82, 2.73, 3.71, 3.23, 3.09, 3.52
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Sokoto State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    2.32, 2.02, 1.82, 1.99, 1.79, 2, 2.88, 2.04, 2.77, 2.41, 2.31, 2.63
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Taraba State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    1.78, 2.04, 1.85, 2.02, 1.81, 2.02, 2.91, 2.06, 2.8, 2.44, 2.34, 2.65
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Yobe State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
y = [
    1.78, 1.89, 1.7, 1.89, 1.68, 1.87, 2.65, 1.89, 2.57, 2.24, 2.14, 2.43
     ]

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x_pos, y, color='black')
plt.title('FAAC Statistics for Zamfara State\n')
plt.xlabel('Months of the Year')
plt.ylabel('Total Allocation in Billions')
plt.xticks(x_pos, x)

# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
# Customize the minor grid
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%.2f' %float(height),
            ha='center', va='bottom')
autolabel(rects1)

plt.show()
